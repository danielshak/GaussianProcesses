# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
from matplotlib import cm
import GPy
from sklearn.metrics import mean_squared_error

np.random.seed(1)
# %matplotlib inline

# %%
vsp_data = pd.read_csv('../Data/vsp_input.tsv',sep='\t')
chrm1_data = vsp_data[vsp_data['AvgChrs']<=1]
chrm1_data = chrm1_data[chrm1_data['WSU_Old']!=17]
chrm1_data.head()
# Out:
#     Gene.names                                Gene.description   AvgChrs  \
# 46       Acadl       acyl-Coenzyme A dehydrogenase, long-chain  0.341978
# 53       Acbd3     acyl-Coenzyme A binding domain containing 3  0.924634
# 88      Actr1b  ARP1 actin-related protein 1B, centractin beta  0.187783
# 90       Actr3                    ARP3 actin-related protein 3  0.641597
# 102     Adhfe1       alcohol dehydrogenase, iron containing, 1  0.048929
#
#      AT2_18M_F10    WSU_Old  Gene start (bp)  Gene end (bp)  gene length
# 46      7.217256  28.021149         66830839       66863277        32438
# 53      5.820596  24.807548        180726043      180754204        28161
# 88      6.712477  25.467643         36698114       36714422        16308
# 90      7.504811  26.892912        125392905      125435727        42822
# 102     2.993626  22.029780          9547948        9580673        32725

# %%
vsp_data=vsp_data[vsp_data['WSU_Old']!=17]
vsp_data=vsp_data[vsp_data['AT2_18M_F10']!=0]
fig = plt.figure()
fig.set_size_inches(24,24)
# ax = fig.add_subplot(211)
# sc = ax.scatter(vsp_data['AvgChrs'],vsp_data['AT2_18M_F10'],c=vsp_data['WSU_Old'],cmap = cm.viridis,alpha=0.5)
# ax.set_xlabel('Chromosome Position')
# ax.set_ylabel('RNA-seq')
# plt.colorbar(sc)

ax2 = fig.add_subplot(111)
sc = ax2.scatter(np.log2(vsp_data['gene length']),vsp_data['AT2_18M_F10'],c=vsp_data['WSU_Old'],cmap = cm.viridis,alpha=0.5)
ax2.set_xlabel('Gene Length')
ax2.set_ylabel('RNA-seq')
plt.colorbar(sc)

# %%
# %matplotlib inline
fig = plt.figure()
fig.set_size_inches(12,6)
ax = fig.add_subplot(121)
sc = ax.scatter(chrm1_data['AvgChrs'],chrm1_data['AT2_18M_F10'],c=chrm1_data['WSU_Old'],cmap = cm.viridis)
ax.set_xlabel('Chromosome Position')
ax.set_ylabel('RNA-seq')
plt.colorbar(sc)

ax2 = fig.add_subplot(122)
sc = ax2.scatter(np.log2(chrm1_data['gene length']),chrm1_data['AT2_18M_F10'],c=chrm1_data['WSU_Old'],cmap = cm.viridis)
ax2.set_xlabel('Gene Length')
ax2.set_ylabel('RNA-seq')
plt.colorbar(sc)

# %%
#Subset data into different partitions to test how much data the GP needs
data_percent = 0.8

msk = np.random.rand(len(chrm1_data)) < data_percent
train_chrm1 = chrm1_data[msk]
test_chrm1 = chrm1_data[~msk]

# %% [markdown]
# ### Training Data

# %%
x=train_chrm1[['gene length','AT2_18M_F10']].values
x[:,0]=np.log2(x[:,0])
y=train_chrm1[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

# %% [markdown]
# ### Testing Data

# %%
x_test = test_chrm1[['gene length','AT2_18M_F10']].values
x_test[:,0]=np.log2(x_test[:,0])

y_truth=test_chrm1[['WSU_Old']].values
#Make sure to use to original avg from the training data
y_truth -= avg_protein

# %% [markdown]
# ### GP model using log2 gene length

# %%
m = GPy.models.GPRegression(x,y)

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# ### GP model using avg chrm position

# %%
x=train_chrm1[['AvgChrs','AT2_18M_F10']].values
y=train_chrm1[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

# %%
m2 = GPy.models.GPRegression(x,y)

# %%
_ = m2.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)

# %% [markdown]
# ## 4d GP

# %%
x=train_chrm1[['AvgChrs','gene length','AT2_18M_F10']].values
x[:,1]=np.log2(x[:,1])
y=train_chrm1[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

# %%
x_test = test_chrm1[['AvgChrs','gene length','AT2_18M_F10']].values
x_test[:,1]=np.log2(x_test[:,1])

# %%
m3 = GPy.models.GPRegression(x,y)

# %%
m3.optimize(messages=1, ipython_notebook=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
predicted = m3.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]

# %%
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.926581734478266

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.69656721]), array([5.97576975e-07]))

# %%
plt.scatter(y_truth,y_predicted)

# %% [markdown]
# # Sticking with gene length cont.

# %%
x=train_chrm1[['gene length','AT2_18M_F10']].values
x[:,0]=np.log2(x[:,0])
y=train_chrm1[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

# %%
x_test = test_chrm1[['gene length','AT2_18M_F10']].values
x_test[:,0]=np.log2(x_test[:,0])

y_truth=test_chrm1[['WSU_Old']].values
#Make sure to use to original avg from the training data
y_truth -= avg_protein

# %%
m = GPy.models.GPRegression(x,y)
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 267.37870527553076<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
ax.set_title(f'rbf kernel with lengthscale {m.rbf.lengthscale[0]},{data_percent} percent data')
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# Text(0.5, 1.0, 'rbf kernel with lengthscale 1.0,0.8 percent data')
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
predicted = m.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.889902334363562

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.69372996]), array([6.93409699e-07]))

# %%
plt.scatter(y_truth,y_predicted)

# %% [markdown]
# # Optimized method

# %%
m.optimize(messages=1, ipython_notebook=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
ax.set_title(f'rbf kernel with lengthscale {m.rbf.lengthscale[0]},{data_percent} percent data')
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# Text(0.5, 1.0, 'rbf kernel with lengthscale 4.621611393508478,0.8 percent data')
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
predicted = m.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.9106476378436128

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.70246842]), array([4.36171867e-07]))

# %%
plt.scatter(y_truth,y_predicted)

# %% [markdown]
# # Very small length scale, see that it is overfitting

# %%
m.rbf.lengthscale[:] = 0.1
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 292.7321765077543<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>             value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>1.7468971807792961</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>               0.1</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>1.2931650695787928</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
ax.set_title(f'rbf kernel with lengthscale {m.rbf.lengthscale[0]},{data_percent} percent data')
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# Text(0.5, 1.0, 'rbf kernel with lengthscale 0.1,0.8 percent data')
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # Using all the data

# %%
vsp_data=vsp_data[vsp_data['WSU_Old']!=17]
vsp_data=vsp_data[vsp_data['AT2_18M_F10']!=0]

# %% [markdown]
# ### Split into training and testing

# %%
#Subset data into different partitions to test how much data the GP needs
data_percent = 0.8

msk = np.random.rand(len(vsp_data)) < data_percent
train_data = vsp_data[msk]
test_data = vsp_data[~msk]

# %%
#TRAINING
x = train_data[['gene length','AT2_18M_F10']].values
x[:,0]=np.log2(x[:,0])

y=train_data[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

#TESTING
x_test = test_data[['gene length','AT2_18M_F10']].values
x_test[:,0]=np.log2(x_test[:,0])

y_truth=test_data[['WSU_Old']].values
#Make sure to use to original avg from the training data
y_truth -= avg_protein

# %%
m = GPy.models.GPRegression(x,y)
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 5017.125173824521<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
ax.set_title(f'rbf kernel with lengthscale {m.rbf.lengthscale[0]},{data_percent} percent data')
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# Text(0.5, 1.0, 'rbf kernel with lengthscale 1.0,0.8 percent data')
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
predicted = m.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.8314908803464067

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.45669813]), array([5.62425389e-38]))

# %%
plt.scatter(y_truth,y_predicted)

# %%
m.optimize(messages=1, ipython_notebook=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
_ = m.plot()
ax = plt.gca()
mappable=ax.collections[0]
plt.colorbar(mappable)
ax.set_title(f'rbf kernel with lengthscale {m.rbf.lengthscale[0]},{data_percent} percent data')
# Out:
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# Text(0.5, 1.0, 'rbf kernel with lengthscale 4.296442020466164,0.8 percent data')
#  /home/balchlab/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
predicted = m.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.7762773525492441

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.48109516]), array([1.60330757e-42]))

# %%
plt.scatter(y_truth,y_predicted)

# %% [markdown]
# ## 4D using all the data

# %%
x=train_data[['AvgChrs','gene length','AT2_18M_F10']].values
x[:,1]=np.log2(x[:,1])
y=train_data[['WSU_Old']].values
avg_protein = y.mean()
y -= avg_protein

x_test = test_data[['AvgChrs','gene length','AT2_18M_F10']].values
x_test[:,1]=np.log2(x_test[:,1])

# %%
m3 = GPy.models.GPRegression(x,y)

# %%
m3.optimize(messages=1, ipython_notebook=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
predicted = m3.predict(x_test) #reurns mean and variance
y_predicted = predicted[0]
mean_squared_error(y_truth,y_predicted)
# Out:
# 1.7834530325405666

# %%
pearsonr = scipy.stats.pearsonr(y_truth,y_predicted)
print(pearsonr)
# Out:
# (array([0.47792957]), array([6.54129578e-42]))

# %%
plt.scatter(y_truth,y_predicted)
